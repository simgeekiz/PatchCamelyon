# %%
# %load_ext autoreload
# %autoreload 2
import os
from keras.utils import HDF5Matrix

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")

# %%
from utils.load_data import load_data

# %%
data_dir = '../data/macenko'
norm = 'macenko_1_10000'

x_train = HDF5Matrix(os.path.join(data_dir, 'camelyonpatch_level_2_split_train_x_' + norm + '.h5.gz') , 'x')

len(x_train)
# Out:
# 9989

# %%
plt.figure(figsize=(8,5))
plt.imshow(x_train[0])
# Out:
# W0510 10:15:28.979935 140718312546432 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
data_dir = '../data/macenko'

x_test, y_test = load_data(data_dir, purpose='test', norm='macenko')

# %%
plt.figure(figsize=(8,5))
plt.imshow(x_test[0])
# Out:
# W0510 10:16:36.319814 140718312546432 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
data_dir = '../data/'

x_train_org, *_ = load_data(data_dir, purpose='train', limit=300, val_limit=300)
len(x_train)
# Out:
# 9989

# %%
x_train_org[0]
# Out:
# array([[[226, 209, 225],
#         [224, 210, 225],
#         [223, 211, 223],
#         ...,
#         [218, 178, 230],
#         [214, 182, 221],
#         [188, 161, 192]],
#
#        [[223, 209, 224],
#         [222, 210, 224],
#         [221, 211, 222],
#         ...,
#         [127,  87, 150],
#         [159, 126, 181],
#         [204, 176, 225]],
#
#        [[222, 210, 224],
#         [221, 210, 224],
#         [219, 211, 222],
#         ...,
#         [ 77,  38, 117],
#         [ 42,   8,  84],
#         [137, 107, 179]],
#
#        ...,
#
#        [[123,  81, 165],
#         [128,  90, 173],
#         [126,  91, 173],
#         ...,
#         [203, 135, 210],
#         [226, 155, 223],
#         [202, 130, 194]],
#
#        [[ 90,  52, 139],
#         [ 90,  56, 142],
#         [ 79,  45, 131],
#         ...,
#         [216, 152, 230],
#         [179, 113, 185],
#         [217, 152, 220]],
#
#        [[ 85,  51, 138],
#         [101,  68, 155],
#         [ 91,  59, 144],
# ...

# %%
plt.figure(figsize=(8,5))
plt.imshow(x_train[0])
